# %%
#Please execute this notebook on the course python environment
#This installs all the pre-requisities for the course

# !pip install tensorflow===2.10.0
# !pip install torch
# !pip install keras===2.10.0
# !pip install transformers
# !pip install datasets
# !pip install sentencepiece
# !pip install evaluate
# !pip install nltk
# !pip install rouge_score
# Out:
# Collecting tensorflow===2.10.0
#   Downloading tensorflow-2.10.0-cp310-cp310-macosx_10_14_x86_64.whl (241.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 MB 857.0 kB/s eta 0:00:0000:0100:03
# Requirement already satisfied: absl-py>=1.0.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (3.9.0)
# Collecting keras-preprocessing>=1.1.1 (from tensorflow===2.10.0)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 772.6 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: libclang>=13.0.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (16.0.6)
# Requirement already satisfied: numpy>=1.20 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (3.3.0)
# Requirement already satisfied: packaging in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (22.0)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow===2.10.0)
#   Downloading protobuf-3.19.6-py2.py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 353.6 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: setuptools in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (65.4.1)
# Requirement already satisfied: six>=1.12.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorflow===2.10.0) (1.58.0)
# Collecting tensorboard<2.11,>=2.10 (from tensorflow===2.10.0)
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 1.7 MB/s eta 0:00:0000:0100:01
# Collecting tensorflow-estimator<2.11,>=2.10.0 (from tensorflow===2.10.0)
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 1.6 MB/s eta 0:00:0000:0100:01
# Collecting keras<2.11,>=2.10.0 (from tensorflow===2.10.0)
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 1.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow===2.10.0) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.23.0)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.11,>=2.10->tensorflow===2.10.0)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.28.2)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.11,>=2.10->tensorflow===2.10.0)
#   Downloading tensorboard_data_server-0.6.1-py3-none-macosx_10_9_x86_64.whl (3.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 2.1 MB/s eta 0:00:0000:0100:01
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.11,>=2.10->tensorflow===2.10.0)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 2.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.3.7)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (4.9)
# Requirement already satisfied: urllib3<2.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (1.26.14)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow===2.10.0) (3.2.2)
# Installing collected packages: tensorboard-plugin-wit, keras, tensorflow-estimator, tensorboard-data-server, protobuf, keras-preprocessing, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.13.1
#     Uninstalling keras-2.13.1:
#       Successfully uninstalled keras-2.13.1
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.13.0
#     Uninstalling tensorflow-estimator-2.13.0:
#       Successfully uninstalled tensorflow-estimator-2.13.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.1
#     Uninstalling tensorboard-data-server-0.7.1:
#       Successfully uninstalled tensorboard-data-server-0.7.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.24.3
#     Uninstalling protobuf-4.24.3:
#       Successfully uninstalled protobuf-4.24.3
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.13.0
#     Uninstalling tensorboard-2.13.0:
#       Successfully uninstalled tensorboard-2.13.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.13.0
#     Uninstalling tensorflow-2.13.0:
#       Successfully uninstalled tensorflow-2.13.0
# Successfully installed google-auth-oauthlib-0.4.6 keras-2.10.0 keras-preprocessing-1.1.2 protobuf-3.19.6 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0
# Requirement already satisfied: torch in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (2.0.1)
# Requirement already satisfied: filelock in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from torch) (3.12.3)
# Requirement already satisfied: typing-extensions in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: keras===2.10.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (2.10.0)
# Requirement already satisfied: transformers in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (4.33.1)
# Requirement already satisfied: filelock in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from transformers) (3.12.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from transformers) (0.17.1)
# Requirement already satisfied: numpy>=1.17 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from transformers) (22.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from transformers) (2023.8.8)
# Requirement already satisfied: requests in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from transformers) (2.28.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from transformers) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from requests->transformers) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: datasets in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (2.14.5)
# Requirement already satisfied: numpy>=1.17 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from datasets) (1.24.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from datasets) (13.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: requests>=2.19.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from datasets) (2.28.2)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from datasets) (3.3.0)
# Requirement already satisfied: multiprocess in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from datasets) (3.8.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from datasets) (0.17.1)
# Requirement already satisfied: packaging in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from datasets) (22.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from aiohttp->datasets) (3.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.12.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: sentencepiece in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (0.1.99)
# Requirement already satisfied: evaluate in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (0.4.0)
# Requirement already satisfied: datasets>=2.0.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from evaluate) (2.14.5)
# Requirement already satisfied: numpy>=1.17 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from evaluate) (1.24.3)
# Requirement already satisfied: dill in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from evaluate) (0.3.7)
# Requirement already satisfied: pandas in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from evaluate) (2.0.2)
# Requirement already satisfied: requests>=2.19.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from evaluate) (2.28.2)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from evaluate) (4.66.1)
# Requirement already satisfied: xxhash in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from evaluate) (3.3.0)
# Requirement already satisfied: multiprocess in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from evaluate) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from evaluate) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from evaluate) (0.17.1)
# Requirement already satisfied: packaging in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from evaluate) (22.0)
# Requirement already satisfied: responses<0.19 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (13.0.0)
# Requirement already satisfied: aiohttp in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (3.8.5)
# Requirement already satisfied: pyyaml>=5.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from datasets>=2.0.0->evaluate) (6.0)
# Requirement already satisfied: filelock in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate) (3.12.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from requests>=2.19.0->evaluate) (2022.12.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from pandas->evaluate) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from pandas->evaluate) (2023.3)
# Requirement already satisfied: attrs>=17.3.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: six>=1.5 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Requirement already satisfied: nltk in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from nltk) (4.66.1)
# Requirement already satisfied: rouge_score in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (0.1.2)
# Requirement already satisfied: absl-py in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from rouge_score) (3.8.1)
# Requirement already satisfied: numpy in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from rouge_score) (1.24.3)
# Requirement already satisfied: six>=1.14.0 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from nltk->rouge_score) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from nltk->rouge_score) (2023.8.8)
# Requirement already satisfied: tqdm in /Users/samuele/Documents/Data_Science/.venv/lib/python3.10/site-packages (from nltk->rouge_score) (4.66.1)
